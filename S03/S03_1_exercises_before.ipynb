# %% [markdown]
# # Text Tokenization Exercise
#
# This exercise explores the challenges of splitting text into sentences and words when dealing with complex real-world text containing dates, amounts, URLs, emails, acronyms, and multi-word expressions.

# %% [markdown]
# ## The Challenge
#
# Given a text variable, split it into:
# 1. **Sentences** - logical units of meaning ending with terminal punctuation
# 2. **Words (tokens)** - individual meaningful units

# %%
# Sample text with challenging elements
text = """Dr. John Smith, Ph.D., earned $1,250.50 on Jan. 15, 2024, for his work at A.I. Corp. You can reach him at j.smith@ai-corp.co.uk or visit https://www.ai-corp.co.uk/team/dr-smith for more info. The U.S.A.-based company reported a 23.5% increase in Q3 revenue, totaling €2.5M."""

print("Original text:")
print(text)
# Out:
# Original text:
# Dr. John Smith, Ph.D., earned $1,250.50 on Jan. 15, 2024, for his work at A.I. Corp. You can reach him at j.smith@ai-corp.co.uk or visit https://www.ai-corp.co.uk/team/dr-smith for more info. The U.S.A.-based company reported a 23.5% increase in Q3 revenue, totaling €2.5M.

# %%
# Tokenizing the text into words

words = text.split()
print(words)
# Out:
# ['Dr.', 'John', 'Smith,', 'Ph.D.,', 'earned', '$1,250.50', 'on', 'Jan.', '15,', '2024,', 'for', 'his', 'work', 'at', 'A.I.', 'Corp.', 'You', 'can', 'reach', 'him', 'at', 'j.smith@ai-corp.co.uk', 'or', 'visit', 'https://www.ai-corp.co.uk/team/dr-smith', 'for', 'more', 'info.', 'The', 'U.S.A.-based', 'company', 'reported', 'a', '23.5%', 'increase', 'in', 'Q3', 'revenue,', 'totaling', '€2.5M.']

# %%
# Tokenizing the text into sentences

import re
def sentence(text):
    sentence_endings = re.compile(r'(?<=[.!?]) +')
    return re.split(sentence_endings, text)
print(sentence(text))
# Out:
# ['Dr.', 'John Smith, Ph.D., earned $1,250.50 on Jan.', '15, 2024, for his work at A.I.', 'Corp.', 'You can reach him at j.smith@ai-corp.co.uk or visit https://www.ai-corp.co.uk/team/dr-smith for more info.', 'The U.S.A.-based company reported a 23.5% increase in Q3 revenue, totaling €2.5M.']

# %% [markdown]
# ## Using given tools

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# 1. Sentence splitting
sentences = sent_tokenize(text)

# 2. Word tokenization
tokens = word_tokenize(text)

print("NLTK – Sentences:")
for s in sentences:
    print("-", s)

print("\nNLTK – Tokens:")
print(tokens)
# Out:
# NLTK – Sentences:
# - Dr. John Smith, Ph.D., earned $1,250.50 on Jan. 15, 2024, for his work at A.I.
# - Corp. You can reach him at j.smith@ai-corp.co.uk or visit https://www.ai-corp.co.uk/team/dr-smith for more info.
# - The U.S.A.-based company reported a 23.5% increase in Q3 revenue, totaling €2.5M.
#
# NLTK – Tokens:
# ['Dr.', 'John', 'Smith', ',', 'Ph.D.', ',', 'earned', '$', '1,250.50', 'on', 'Jan.', '15', ',', '2024', ',', 'for', 'his', 'work', 'at', 'A.I', '.', 'Corp.', 'You', 'can', 'reach', 'him', 'at', 'j.smith', '@', 'ai-corp.co.uk', 'or', 'visit', 'https', ':', '//www.ai-corp.co.uk/team/dr-smith', 'for', 'more', 'info', '.', 'The', 'U.S.A.-based', 'company', 'reported', 'a', '23.5', '%', 'increase', 'in', 'Q3', 'revenue', ',', 'totaling', '€2.5M', '.']

# %% [markdown]
# # Corpus Tokenization Exercise
#
# This exercise explores the challenges of splitting words in large corpuses and find the most common words.

# %%
import nltk
from nltk.tokenize import word_tokenize
from collections import Counter

nltk.download("punkt", quiet=True)

tokens = word_tokenize(text)
tokens = [t.lower() for t in tokens]
tokens = [t for t in tokens if t.isalpha()]


word_counts = Counter(tokens)
top10_words = word_counts.most_common(10)

print("Top 10 words:")
for w, c in top10_words:
    print(w, c)
# Out:
# Top 10 words:
# for 2
# at 2
# john 1
# smith 1
# earned 1
# on 1
# his 1
# work 1
# you 1
# can 1

# %% [markdown]
# ## The Challenge
#
# Given a file `shakes.txt` in the book folder. Find the words that are more common in Shakespeare's book.

# %%
from nltk.tokenize import word_tokenize
from collections import Counter

text= open("C:\\Users\\usuario\\Desktop\\UIE\\Semestre 2\\01 Speech & Language Processing\\speech_and_language_processing\\S03\\Books-20260126\\shakes.txt").read()

tokens = word_tokenize(text)
tokens = [t.lower() for t in tokens]
tokens = [t for t in tokens if t.isalpha()]

word_counts = Counter(tokens)

most_common_words = word_counts.most_common()

print("Most common words:")
print(most_common_words)
# Out:
# Most common words:
# [('the', 27777), ('and', 26770), ('i', 22416), ('to', 19243), ('of', 18288), ('a', 14712), ('you', 13849), ('my', 12462), ('that', 11513), ('in', 11048), ('is', 11000), ('not', 9474), ('for', 8255), ('with', 8042), ('me', 7712), ('it', 7705), ('be', 7082), ('your', 6878), ('this', 6865), ('his', 6850), ('he', 6660), ('but', 6262), ('as', 5963), ('have', 5883), ('thou', 5472), ('so', 5247), ('him', 5159), ('will', 4971), ('what', 4782), ('by', 4436), ('thy', 4030), ('all', 3918), ('are', 3869), ('her', 3837), ('no', 3776), ('do', 3758), ('we', 3611), ('shall', 3585), ('if', 3510), ('or', 3193), ('thee', 3163), ('on', 3085), ('our', 3065), ('lord', 3042), ('king', 3022), ('good', 2793), ('now', 2763), ('sir', 2735), ('o', 2705), ('from', 2660), ('they', 2528), ('at', 2521), ('come', 2499), ('she', 2395), ('was', 2382), ('let', 2346), ('which', 2320), ('here', 2309), ('would', 2291), ('more', 2281), ('then', 2211), ('there', 2191), ('am', 2161), ('how', 2159), ('well', 2137), ('love', 2122), ('enter', 2106), ('their', 2078), ('when', 2041), ('can', 1987), ('man', 1981), ('them', 1957), ('hath', 1938), ('than', 1884), ('may', 1878), ('an', 1834), ('one', 1784), ('upon', 1735), ('go', 1722), ('like', 1702), ('us', 1670), ('say', 1669), ('know', 1639), ('make', 1632), ('did', 1622), ('such', 1621), ('should', 1573), ('were', 1573), ('yet', 1560), ('must', 1501), ('why', 1458), ('see', 1437), ('had', 1425), ('out', 1366), ('give', 1334), ('some', 1333), ('where', 1331), ('these', 1323), ('time', 1296), ('who', 1274), ('too', 1224), ('take', 1195), ('most', 1183), ('mine', 1159), ('first', 1158), ('speak', 1156), ('th', 1150), ('duke', 1126), ('up', 1066), ('tell', 1055), ('father', 1054), ('exeunt', 1035), ('much', 1031), ('heart', 1021), ('think', 1019), ('never', 1007), ('exit', 984), ('any', 974), ('nor', 969), ('queen', 966), ('doth', 939), ('men', 935), ('lady', 919), ('look', 917), ('art', 915), ('great', 896), ('world', 891), ('god', 884), ('death', 874), ('hear', 870), ('away', 857), ('life', 842), ('before', 831), ('master', 831), ('hand', 829), ('made', 827), ('very', 813), ('scene', 794), ('sweet', 786), ('true', 782), ('own', 770), ('prince', 770), ('thus', 764), ('again', 759), ('fair', 753), ('ay', 748), ('day', 745), ('pray', 745), ('call', 732), ('other', 717), ('old', 712), ('two', 699), ('been', 695), ('son', 692), ('eyes', 679), ('long', 673), ('fear', 665), ('being', 661), ('name', 659), ('leave', 648), ('night', 648), ('down', 648), ('heaven', 647), ('done', 643), ('into', 640), ('both', 639), ('blood', 633), ('brother', 630), ('nothing', 628), ('though', 626), ('therefore', 624), ('could', 622), ('poor', 622), ('honour', 620), ('till', 616), ('whose', 615), ('comes', 615), ('noble', 612), ('henry', 608), ('gloucester', 607), ('caesar', 600), ('against', 593), ('better', 591), ('ever', 590), ('grace', 590), ('hast', 583), ('nay', 578), ('second', 574), ('many', 572), ('even', 570), ('way', 562), ('stand', 561), ('myself', 560), ('use', 558), ('still', 550), ('those', 545), ('john', 544), ('house', 541), ('bear', 534), ('only', 533), ('wife', 533), ('peace', 531), ('france', 524), ('dead', 523), ('find', 522), ('richard', 520), ('gentleman', 514), ('head', 513), ('antony', 513), ('live', 510), ('part', 508), ('madam', 502), ('within', 498), ('word', 496), ('might', 495), ('put', 495), ('every', 491), ('york', 491), ('brutus', 482), ('keep', 479), ('little', 478), ('off', 478), ('show', 476), ('fool', 475), ('die', 470), ('electronic', 469), ('set', 469), ('none', 464), ('aside', 464), ('gone', 463), ('friends', 463), ('young', 462), ('lords', 461), ('hold', 459), ('stay', 459), ('thine', 456), ('copies', 453), ('another', 453), ('soul', 452), ('falstaff', 451), ('mistress', 449), ('distributed', 447), ('since', 447), ('best', 446), ('dear', 445), ('himself', 444), ('bring', 444), ('service', 440), ('page', 440), ('friend', 438), ('indeed', 435), ('mother', 432), ('full', 429), ('unto', 428), ('dost', 427), ('place ...
